# %% [markdown]
# # Программирование на языке Python
# ## Семинар 1
# ### Знакомимся!
# <u>Немного обо мне:</u>
# - меня зовут Иоанн;
# - я ваш преподаватель, а еще...
# - DS-engineer в Сбере;
# - преподаватель в ВШЭ.
#
# <u>А вы кто?</u>
# - почему вы решили учиться на этой программе?
# - что ожидаете получить от этого курса?
#
# ### Немного советов прежде начала
# - если вы раньше не программировали, научиться программировать за этот курс не получится;
# - **НО:** получится научиться учиться программировать (дальше вы будете делать это все время)!
#
# #### N советов перед выполнением любой задачи
# - **ВСЕГДА** изначально представляйте себе definition of done;
# - декомпозируйте задачу на подзадачи;
# - поймите, знаете ли вы какой инструмент использовать для решения каждой из них;
# - если не знаете: 1) гуглите и 2) ищите в [документации](https://docs.python.org/3/);
# - если непонятно, с какой стороны вообще подступиться: 1) спрашивайте у менторов, 2) спрашивайте у преподавателя, (3) у ваших старших коллег);
# - **ВАЖНО:** никогда не стесняйтесь задавать вопросы, если что-то не поняли. Помните: чтобы понять некоторые вещи (не все), надо попробовать сделать это много раз.
#
# #### Учимся мыслить "питонически"
# Чтобы лучше понимать, как устроен и как работает Python, надо научиться воспринимать все в виде классов и объектов. Это далеко не так сложно, как кажется на первый взгляд. К примеру, есть вид _homo sapiens_. Мы можем перечислить его базовые характеристики: двуногий, говорящий, социальный и т. д. Однако в деталях люди, как мы знаем, разные: они отличаются по полу, возрасту, именам, характеру и т. п. И в то же время мы понимаем, что у нас есть очень много общего: мы принадлежим к одному *классу*, являясь каждый уникальным *объектом* этого класса. То есть: класс - идеальная форма, а объект - конкретное выражение этой формы.
#
# В общей сложности, **каждый объект какого-то класса обладает:**
#
# * описательными чертами (что это: какого цвета, сколько весит) - в Питоне мы будем называть это *атрибутами*;
# * определенным набором возможных действий (что оно может делать) - в парадигме Python мы будем называть это *методами*.
#
# Далее, нам следует понимать, что Python (как язык программирования) является своеобразной "реальностью" полностью и с нуля сконструированной людьми. Как и в реальном мире, в Питоне происходят какие-то взаимодействия между разными объектами. Разница лишь в том, что в жизни мы изучаем, как это происходит, а в Python мы сами устанавливаем правила взаимодействия. Например, Питон *знает*, что `1 + 1 = 2` по следующим причинам:
#
# * программисты, написавшие Python, определили, что такое целое число (в этом случае `1` - это конкретный объект класса "целове число");
# * они же определили (запрограммировали), что будет, если одно целое число встретит `+` в компании другого целого числа.
#
# Вы можете определить СВОЙ СОБСТВЕННЫЙ КЛАСС и самостоятельно решить, как он будет работать при сложении с чем-либо (к примеру, может просто печататься сообщение "Вы прекрасны!").
#
# Так что не следует пугаться, если какой-либо оператор (`+`, `-`, `=` и т. д.) или функция ведут себя неожиданным образом: просто откройте документацию и посмотрите как оно должно работать.
#
# **Вопрос.** Как вы думаете, что должно произойти в следующей ячейке?

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# А в этой?

# %%
'1' + '1'
# Out:
# '11'

# %% [markdown]
# Понятное дело, в реальной жизни такого не случается.
#
# #### Функции
# В Питоне вы всегда и везде будете встречать функции. Но что они такое? Что вы помните о них со школы?
#
# Функция, это инструмент, который:
#
# * берет что-то на вход (к примеру, ингридиенты для торта). Мы будем называть это *аргументами функции*;
# * выполняет какую-то операцию (например, смешивает ингридиенты вместе);
# * что-то возвращает обратно (в нашем случае вкусный торт).
#
# **Важно.** Если вы хотите понять, как работает та или иная функция, вы должны проверить все три пункта. В документации они обычно указываются отдельно.
#
# Обычная функция в Python выглядит так: `function(arg1, arg2, ...)`.
#
# Пример с функцией `print`:

# %%
print(1, 2, 3)
# Out:
# 1 2 3

# %%
if temp < -5:
    wear_jacket()
elif condition:
    do_something()
else:
    wear_coat()

# %% [markdown]
# # Заголовок 1
# ## Заголовок 2
#
# Текст
#
# **Жирный текст**
#
# *Наклонный текст*
#
# <u>Подчеркнутый текст</u>

# %% [markdown]
# ### Решаем задачи
# #### Задача 1
#
# Напишите программу, которая будет принимать на вход целое либо действительное число, преобразовывать его в соответствующий тип (либо `int`, либо `float`) и печатать его для пользователя (в преобразованном виде).
#
# **Примечание.** Пользователь может ввести только целое или действительное число (с точкой).
#
# 1. Надо попросить пользователя ввести число (`input()`);
# 2. Понять, входит ли точка (`.` в строку). Можно использовать метод `.find()`;
# 3. Преобразовать строку либо в int, либо в float (используя `int()` или `float()`);
# 4. Напечатать для пользователя (`print()`).

# %%
'nn5'.find('5'), 'nn5'.find('6')
# Out:
# (2, -1)

# %%
'5' in 'nn5', '6' in 'nn5'
# Out:
# (True, False)

# %%
number = input()

if number.find('.') != -1:
    result = float(number)
else:
    result = int(number)

print(result)
# Out:
# 4.5
# 4.5

# %%
number, type(number)
# Out:
# ('4.5', str)

# %%
number = input()

if '.' in number:
    result = float(number)
else:
    result = int(number)

print(result)

# %% [markdown]
# #### Задача 2
# Напишите программу, которая будет преобразовывать принятые на вход (в виде строки) списки вида "вода, масло, сок" (слова через запятую) в список вида (вместо точки необходимо использовать дефис)
# ```
# вода
# масло
# сок
# ```
#
# и печатать его для пользователя (в виде, обозначенном выше). Программа должна обращаться к пользователю следующим образом: "Введите слова через запятую".
#
# 1. Надо попросить пользователя ввести слова через запятую (`input()`);
# 2. Надо понять, как именно разделяются слова в вводе (через `, `);
# 3. Надо понять, на что заменить данный разделитель, чтобы функция `print()` напечатала каждое слово с новой строки (`\n`);
# 4. Заменить (`.replace()`);
# 5. Вывести полученное для пользователя.

# %%
'строка1\nстрока2'
# Out:
# 'строка1\nстрока2'

# %%
print('строка1\nстрока2')
# Out:
# строка1
# строка2

# %%
'вода, масло, сок' ->

'''
вода
масло
сок
'''

# %%
'вода, масло, сок'.replace(', ', '\n')
# Out:
# 'вода\nмасло\nсок'

# %%
lst = input('Введите слова через запятую: ')  # ввод

lst = lst.replace(', ', '\n')  # заменяю один разделитель на другой

print(lst)
# Out:
# Введите слова через запятую: один, два, три
# один
# два
# три

# %% [markdown]
# #### Задача 3
#
# Вашу компанию очень интересует, оставляют ли осмысленные отзывы к ее продукции. По мнению контент-менеджера, осмысленный отзыв:
#
# - начинается с заглавной буквы;
# - содержит хотя бы одну запятую;
# - содержит хотя бы 10 слов;
# - не содержит цифр;
# - заканчивается на точку.
#
# **Проверим пока что последний пункт**
#
# Напишите программу, которая принимает на вход отзыв (в виде строки), проверяет все условия и пишет результат для каждого из них. Например:
#
# ```
# Отзыв начинается с заглавной буквы (выполнено).
# Отзыв содержит 3 "," (выполнено).
# Отзыв содержит 2 слов(а) (не выполнено).
# Отзыв содержит цифры (не выполнено).
# Отзыв заканчивается на точку (выполнено).
# ```
#
# 1. Надо запросить от пользователя ввод (`input()`);
# 2.

# %%
feedback = input()  # шаг 1

print(feedback.endswith('.'))

# %%
'aa.'.endswith('.')
# Out:
# True

# %% [markdown]
# #### Задача 4
#
# Напишите программу, которая принимает на вход коэффициенты квадратного уравнения (действительные числа `a`, `b` и `с`) и проверяет, сколько решений оно имеет (2, 1 или 0). Результат должен быть напечатан в виде:
#
# D (дискриминант) = b ** 2 - 4 * a * c
#
# ```
# Квадратное уравнение имеет N корней.
# ```

# %%
a = float(input('Введите коэффициент числа а: '))  # принимаем на вход a
b = float(input('Введите коэффициент числа b: '))  # принимаем на вход b
c = float(input('Введите коэффициент числа c: '))  # принимаем на вход c

D = b ** 2 - 4 * a * c  # рассчитываем дискриминант

if D < 0:  # условие на дискриминант
    N = 0
elif D == 0:
    N = 1
else:
    N = 2

print(f'Квадратное уравнение имеет {N} корней.')  # f-строка
print('Квадратное уравнение имеет {} корней.'.format(N))  # метод .format()
print('Квадратное уравнение имеет', N, 'корней.')  # аргумент по дефолту - sep=' '
print('Квадратное уравнение имеет ' + N + ' корней.')  # конкатенация строк
